# %% [markdown]
# ## Automate Writing the connection message

# %%
import pandas as pd
import numpy as np

data = pd.read_csv('./Data/data.csv')
data.head()# split the name into first and last name for the first name column
greet_message = "Hi, [firstname]! I am Ken, the co-founder at Esger, an NYC startup. We just raised $250k+ and support from top institutions like Cornell, Microsoft, and ERA. As we are using AI to tackle the heart of sustainability issues, the supply chain, I love to connect with experts in the field (like you!)."

data['first_name'] = data['Name'].apply(lambda x: x.split(' ')[0] if type(x) == str else np.nan)
data['greet_message'] = data['first_name'].apply(lambda x: greet_message.replace('[firstname]', x) if type(x) == str else np.nan)

data = data[["Name",'By','greet_message']]

data.to_csv('./Data/processed_data.csv', index=False)

# %% [markdown]
# ## Automate Outputing the name of linkedin Contact

# %%
import pandas as pd
import numpy as np
import re

by_who = "Ken"

greet_message = "Hi, [firstname]! I am Ken, the co-founder at Esger, an NYC startup. We just raised $250k+ and support from top institutions like Cornell, Microsoft, and ERA. As we are using AI to tackle the heart of sustainability issues, the supply chain, I love to connect with experts in the field (like you!)."

input_string = '''https://www.linkedin.com/in/melissa-mardarie-53364117/ | (1) Melissa Mardarie | LinkedIn
https://www.linkedin.com/in/na-yang-977b7b8/ | (1) NA YANG | LinkedIn
https://www.linkedin.com/in/manu-kumra-376a2246/ | (1) Manu Kumra | LinkedIn
https://www.linkedin.com/in/cindylcarter/ | (1) Cindy Carter | LinkedIn
https://www.linkedin.com/in/tyler-feigenbaum-00b2a0ba/ | (1) Tyler Feigenbaum | LinkedIn
https://www.linkedin.com/in/sahithkota/ | (1) Sahith Kota | LinkedIn
https://www.linkedin.com/in/eseiweh/ | (1) Ese Iweh | LinkedIn
https://www.linkedin.com/in/annacalvo/ | (1) Anna Feliza C. | LinkedIn
https://www.linkedin.com/in/caroline-schultheis-8659a31/ | (1) Caroline Schultheis | LinkedIn
https://www.linkedin.com/in/jsanadhya/ | (1) Jaishree Sanadhya | LinkedIn
https://www.linkedin.com/in/vincent-wang-82548735/ | (1) Vincent Wang | LinkedIn
https://www.linkedin.com/in/khonarahul/ | (1) Rahul Khona | LinkedIn
https://www.linkedin.com/in/marinagt/ | (1) Marina M. | LinkedIn
https://www.linkedin.com/in/pragya-tiwari1/ | (1) Pragya Tiwari | LinkedIn
https://www.linkedin.com/in/leann-speta-7221597/ | (1) leann speta | LinkedIn
https://www.linkedin.com/in/jyothi-pingali-4b90977/ | (1) Jyothi Pingali | LinkedIn
https://www.linkedin.com/in/mba-javier-vacas/ | (1) Javier Vacas | LinkedIn
https://www.linkedin.com/in/kanaknakhare/ | (1) Kanak (. | LinkedIn
https://www.linkedin.com/in/laurencesommers/ | (1) Laurence (Elle) Sommers | LinkedIn
https://www.linkedin.com/in/juandelaluz/ | (1) Juan de la Luz, MBA, PMP | LinkedIn
https://www.linkedin.com/in/omardevlin/ | (1) Omar Devlin | LinkedIn
https://www.linkedin.com/in/joannemiranda/ | (1) JoAnne M. | LinkedIn
https://www.linkedin.com/in/amandamdong/ | (1) Amanda Dong | LinkedIn
https://www.linkedin.com/in/avesanielena/ | (1) Elena Avesani | LinkedIn
https://www.linkedin.com/in/lydia-p-1a114a1/ | (1) Lydia (Yu) P. | LinkedIn
https://www.linkedin.com/in/vikramksingla/ | (1) Vikram Singla FCILT | LinkedIn
https://www.linkedin.com/in/lionelalbert/ | (1) Lionel Albert | LinkedIn
https://www.linkedin.com/in/limj/ | (1) Joan Lim | LinkedIn
https://www.linkedin.com/in/steventharris/ | (1) Steve Harris | LinkedIn
https://www.linkedin.com/in/terrihiskey/ | (1) Terri Pruett Hiskey | LinkedIn
https://www.linkedin.com/in/vito-ventura-24b9632/ | (1) Vito Ventura | LinkedIn
https://www.linkedin.com/in/caroline-firer/ | (1) Caroline Firer | LinkedIn
https://www.linkedin.com/in/mariaforney/ | (1) Maria Forney | LinkedIn
https://www.linkedin.com/in/d-michelle/ | (1) Michelle D. | LinkedIn
https://www.linkedin.com/in/davidsiddiqui/ | (1) David Siddiqui | LinkedIn
https://www.linkedin.com/in/johnna-humbert/ | (1) Johnna Humbert | LinkedIn
https://www.linkedin.com/in/ian-murty-77a23220/ | (1) Ian Murty | LinkedIn'''


def remove_special_characters_and_numbers(input_str):
    # Remove all characters that are not alphabets
    clean_str = re.sub(r'[^a-zA-Z\s]', '', input_str)
    return clean_str

# Initialize an empty list to store the names
names_list = []
url_list = []
# Split the input string by lines
for line in input_string.split("\n"):
    # Split each line by the '|' character
    parts = line.split(" | ")

    # The name is the second element in the 'parts' list, strip leading and trailing whitespaces
    url = parts[0].strip()
    name = remove_special_characters_and_numbers(parts[1]).strip()
    
    # Append the name to the list
    names_list.append(name)
    url_list.append(url)


output = pd.DataFrame({"Name":names_list, "Who?":by_who, "LinkedIn Profile":url_list})
output['greet_message'] = output['Name'].apply(lambda x: greet_message.replace('[firstname]', x.split(' ')[0]) if type(x) == str else np.nan)

output.to_csv("./Data/outreach_parsed.csv", index=False)

# %%
output
# Out:
#                  Name Who?                                   LinkedIn Profile  \
# 0    Melissa Mardarie  Ken  https://www.linkedin.com/in/melissa-mardarie-5...
# 1             NA YANG  Ken       https://www.linkedin.com/in/na-yang-977b7b8/
# 2          Manu Kumra  Ken   https://www.linkedin.com/in/manu-kumra-376a2246/
# 3        Cindy Carter  Ken          https://www.linkedin.com/in/cindylcarter/
# 4    Tyler Feigenbaum  Ken  https://www.linkedin.com/in/tyler-feigenbaum-0...
# ..                ...  ...                                                ...
# 96       Maria Forney  Ken           https://www.linkedin.com/in/mariaforney/
# 97         Michelle D  Ken            https://www.linkedin.com/in/d-michelle/
# 98     David Siddiqui  Ken         https://www.linkedin.com/in/davidsiddiqui/
# 99     Johnna Humbert  Ken        https://www.linkedin.com/in/johnna-humbert/
# 100         Ian Murty  Ken    https://www.linkedin.com/in/ian-murty-77a23220/
#
# ...

# %%
import webbrowser
url_list = output['LinkedIn Profile'].tolist()
for url in url_list:
    webbrowser.open(url, new=2)
